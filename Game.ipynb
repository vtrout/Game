# %%
####### PACKAGES and GLOBAL VARIABLES ##################################################################
import ipywidgets as widgets
from IPython.display import display, clear_output, YouTubeVideo
global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
click = '' # session/button unlock/clicks decoded (no duplicates, first click only)
# 0 = 1st session, E = Emerald button unlock, e = emerald button click
case = '0' # the story (patient/location/xray/suspect) ("police notebook") (A/B are two different progress codes)
ID = '0' # student case ID number (multiple different IDs can point to the same case)
code = '' # progress code generated to complete session (unique to A/B case)
####### STUDENT ID and CASE ASSIGNMENT ##################################################################
# need elif for each ID, inside assign case to student
# 01A and 01B point to same case, but A/B are two different progress codes
def IDtoCaseNumber():
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    # ID = number each student is given
    # case = the story (patient/location/xray/suspect) ("police notebook") 
    # A/B are two different progress codes, currently included: case 1-17 A&B
    # additional case numbers or C option for progress codes also could be added
    #!#
    # remove case = 'Z' when updateevidence() case information has been added for that case
    # currently case 01, 06, 12 and 16 have been entered in
    #!#
    #### Case 01 ####
    if ID == '101':
        case = '01A'
    elif ID == '1001':
        case = '01B'
    #Z### Case 02 ####
    elif ID == '102':
        #case = '02A'
        case = 'Z'
    elif ID == '1002':
        #case = '02B'
        case = 'Z'
    #Z### Case 03 ####
    elif ID == '103':
        #case = '03A'
        case = 'Z'
    elif ID == '1003':
        #case = '03B'
        case = 'Z'
    #Z### Case 04 ####
    elif ID == '104':
        #case = '04A'
        case = 'Z'
    elif ID == '1004':
        #case = '04B'
        case = 'Z'
    #Z### Case 05 ####
    elif ID == '105':
        #case = '05A'
        case = 'Z'
    elif ID == '1005':
        #case = '05B'
        case = 'Z'
    #### Case 06 ####
    elif ID == '106':
        case = '06A'
    elif ID == '1006':
        case = '06B'
    #Z### Case 07 ####
    elif ID == '107':
        #case = '07A'
        case = 'Z'
    elif ID == '1007':
        #case = '07B'
        case = 'Z'
    #Z### Case 08 ####
    elif ID == '108':
        #case = '08A'
        case = 'Z'
    elif ID == '1008':
        #case = '08B'
        case = 'Z'
    #Z### Case 09 ####
    elif ID == '109':
        #case = '09A'
        case = 'Z'
    elif ID == '1009':
        #case = '09B'
        case = 'Z'
    #Z### Case 10 ####
    elif ID == '110':
        #case = '10A'
        case = 'Z'
    elif ID == '1010':
        #case = '10B'
        case = 'Z'
    #Z### Case 11 ####
    elif ID == '111':
        #case = '11A'
        case = 'Z'
    elif ID == '1011':
        #case = '11B'
        case = 'Z'
    #### Case 12 ####
    elif ID == '112':
        case = '12A'
    elif ID == '1012':
        case = '12B'
    #Z### Case 13 ####
    elif ID == '113':
        #case = '13A'
        case = 'Z'
    elif ID == '1013':
        #case = '13B'
        case = 'Z'
    #Z### Case 14 ####
    elif ID == '114':
        #case = '14A'
        case = 'Z'
    elif ID == '1014':
        #case = '14B'
        case = 'Z'
    #Z### Case 15 ####
    elif ID == '115':
        #case = '15A'
        case = 'Z'
    elif ID == '1015':
        #case = '15B'
        case = 'Z'
    #### Case 16 ####
    elif ID == '116':
        case = '16A'
    elif ID == '1016':
        case = '16B'
    #Z### Case 17 ####
    elif ID == '117':
        #case = '17A'
        case = 'Z'
    elif ID == '1017':
        #case = '17B'       
        case = 'Z'
    #### Case ?? ####
    else:
        case = 'Z' # ID not defined
####### CASE SPECIFICS: Patient/Injury, Button Order, Progress Code ##############################################
def CaseDictionary():
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
#---# Patient + Injury #-----------------------------------------------------------------#
    # Dictionary where key = case, object = Patient and Injury combination
    # j = jaw, w = wrist, e=elbow, h=hip
    # O = Outdoors, I = Indoors
    patient_d = {'01':'JwO', '02':'JwI', '03':'JwO', '04':'JhO', '05':'JhI',  # Jane
                 '06':'HwO', '07':'HwI', '08':'HwO', '09':'HhO',  # Henry
                 '10':'CjO', '11':'CjO', '12':'CeO', '14':'CeO',  # Cynthia
                 '13':'MjO', '15':'MjO', '16':'MeO', '17':'MeO',} # Michael

#---# Button Order #---------------------------------------------------------------------------------#      
    # Dictionary where key = action in question, object = required step before
    # button must appear before click    
    case_d = {'w':'W', 'e':'E', 't':'T', 's':'S', 'a':'A', 'r':'R',
              'x':'X', 'm':'M', 'c':'C', 'f':'F', 'h':'H', 'o':'O'} 
    case_d['M'] = 'x'  # click XRay before Medical button can be unlocked
    case_d['W'] = 'm' # click Medical before P_Interview button
    case_d['H'] = 'c' # click Camera before Heights button
    case_d['O'] = 'f' # click Footprints before Shoe Sizes button
    
    # case-specific order for buttons unlock (Camera & Footprints)
    if case[0:2]=='01':          
        case_d['C'] = 'r' # click Ruby -> Camera button
        case_d['F'] = 'e' # click Emerald -> Footprints
    elif case[0:2]=='02':
        case_d['C'] = 's' 
        case_d['F'] = ''
    elif case[0:2]=='03':
        case_d['C'] = 's' 
        case_d['F'] = 'e'
    elif case[0:2]=='04':
        case_d['C'] = 'r' 
        case_d['F'] = 't'
    elif case[0:2]=='05':
        case_d['C'] = 's' 
        case_d['F'] = ''
    elif case[0:2]=='06':
        case_d['C'] = 'r' 
        case_d['F'] = 't'
    elif case[0:2]=='07':
        case_d['C'] = 's' 
        case_d['F'] = ''
    elif case[0:2]=='08':
        case_d['C'] = 'a' 
        case_d['F'] = ''
    elif case[0:2]=='09':
        case_d['C'] = 'r' 
        case_d['F'] = 'e'
    elif case[0:2]=='10':
        case_d['C'] = 'r' 
        case_d['F'] = ''
    elif case[0:2]=='11':
        case_d['C'] = 't' 
        case_d['F'] = ''
    elif case[0:2]=='12':
        case_d['C'] = 'r' 
        case_d['F'] = ''
    elif case[0:2]=='13':
        case_d['C'] = 's' 
        case_d['F'] = 'a'
    elif case[0:2]=='14':
        case_d['C'] = 't' 
        case_d['F'] = 'e'
    elif case[0:2]=='15':
        case_d['C'] = 's' 
        case_d['F'] = ''
    elif case[0:2]=='16':
        case_d['C'] = 'r' 
        case_d['F'] = ''
    elif case[0:2]=='17':
        case_d['C'] = 'r' 
        case_d['F'] = 'e'
    else:
        # no story for that case number
        case = 'Z'
        code = 'Z'
    
#---# Code #----------------------------------------------------------------------------------------#
    # Dictionary where key = 2 length progress code, object = action (session/button/click)
    # unique for each full case number + A/B
    # currently included: case 1-17 A&B
    if case == '01A':
        code_d = {'3r':'0', '0P':'1', 'D8':'2', 'E0':'3', '3q':'i', 'K6':'p', 'T7':'W', '9A':'w',
                     'E2':'E', 'b7':'e', '5d':'T', '3p':'t', '7h':'S', 'F9':'s', '2a':'A', '7H':'a',
                     'g0':'R', 'm2':'r', 'X6':'X', '7Q':'x', '6e':'M', '4P':'m', 'h7':'C', '4o':'c',
                     's1':'F', '4r':'f', '9L':'H', '5b':'h', '9h':'O', 'a9':'o'}
    elif case == '01B':
        code_d = {'d1':'0', '6c':'1', '5Y':'2', '9a':'3', 'K8':'i', 'G2':'p', 'e0':'W', '1M':'w',
                     'f2':'E', 'g5':'e', 't9':'T', 'h6':'t', '2C':'S', '7z':'s', '4m':'A', '4v':'a',
                     'Y2':'R', '8I':'r', '0R':'X', '2w':'x', 'Q5':'M', '8O':'m', 'a8':'C', '01':'c',
                     's8':'F', '9n':'f', '6p':'H', 'l7':'h', '7M':'O', 'Q2':'o'}
    elif case == '02A':
        code_d = {'5o':'0', '9H':'1', 'H9':'2', '3B':'3', 'X3':'i', 'N1':'p', 'R4':'W', 'w9':'w',
                     'I5':'E', '3u':'e', 'l4':'T', '9V':'t', 'u7':'S', '7P':'s', '0T':'A', 'M9':'a',
                     '5W':'R', '8p':'r', 'V2':'X', 'Q9':'x', 'V0':'M', 'H7':'m', 'i5':'C', '0i':'c',
                     '8r':'F', 'p3':'f', '6u':'H', '2I':'h', '6D':'O', 'S9':'o'}
    elif case == '02B':
        code_d = {'3T':'0', '4F':'1', '8K':'2', 'W1':'3', 'N3':'i', '8Q':'p', '4J':'W', '2V':'w',
                     'U7':'E', '6L':'e', '3o':'T', '6m':'t', '9x':'S', 'S2':'s', '6Q':'A', 'r6':'a',
                     'J2':'R', '2b':'r', 'a5':'X', '7J':'x', 'b0':'M', '7A':'m', '8o':'C', 'U6':'c',
                     's5':'F', 'Y5':'f', 'p0':'H', '5p':'h', '3l':'O', '3Q':'o'}
    elif case == '03A':
        code_d = {'5s':'0', '2M':'1', 'z4':'2', 'M8':'3', '1O':'i', 'E4':'p', 'h1':'W', '2F':'w',
                     '1H':'E', '3v':'e', 'e3':'T', '9C':'t', '2c':'S', 'L1':'s', 'u5':'A', '4V':'a',
                     '9b':'R', '5L':'r', 'j9':'X', '2k':'x', '8U':'M', 'H0':'m', 'm5':'C', '3w':'c',
                     '6V':'F', '8L':'f', '3i':'H', '7L':'h', '6K':'O', 'B4':'o'}
    elif case == '03B':
        code_d = {'I8':'0', '7x':'1', '1A':'2', 'A1':'3', 'O8':'i', '5K':'p', 'f4':'W', 'x3':'w',
                     '1s':'E', '9R':'e', '1x':'T', 'F6':'t', '9B':'S', '4y':'s', '3b':'A', 'H4':'a',
                     'a3':'R', 'y0':'r', 'S3':'X', 'w6':'x', '1D':'M', 'O9':'m', '6F':'C', 'Y1':'c',
                     's3':'F', '1v':'f', 'f9':'H', 'y4':'h', 't2':'O', '3c':'o'}
    elif case == '04A':
        code_d = {'9K':'0', '5a':'1', '3a':'2', '7N':'3', 'q0':'i', '0z':'p', 'X0':'W', '0a':'w',
                     'B7':'E', 'g9':'e', '3f':'T', 'S6':'t', 'D0':'S', '5t':'s', 'a4':'A', '0y':'a',
                     '8l':'R', '5i':'r', 'c9':'X', 'u3':'x', 'V4':'M', '0s':'m', 'z8':'C', 'o3':'c',
                     'i4':'F', 'C1':'f', 't8':'H', 'u6':'h', 'q4':'O', 'E1':'o'}
    elif case == '04B':
        code_d = {'r7':'0', 'c4':'1', 'U4':'2', '1i':'3', 'z7':'i', '3A':'p', 'l9':'W', 'U8':'w',
                     'G4':'E', '5M':'e', 'p2':'T', '1L':'t', 'D1':'S', '8E':'s', '0L':'A', 'C6':'a',
                     '7p':'R', '7r':'r', '0U':'X', 'p1':'x', '8c':'M', 'K5':'m', 's4':'C', 'I3':'c',
                     'x6':'F', '2i':'f', 'B0':'H', 'v2':'h', '5z':'O', '0H':'o'}
    elif case == '05A':
        code_d = {'G9':'0', '2B':'1', '5D':'2', 'd9':'3', '8e':'i', '5x':'p', 'm0':'W', '2f':'w',
                     'l5':'E', 'v1':'e', 'S4':'T', 'Y7':'t', 'r4':'S', 'L3':'s', 'O4':'A', '0k':'a',
                     '1r':'R', 'A7':'r', 'o2':'X', 'j0':'x', '9S':'M', '3z':'m', '5j':'C', 'S8':'c',
                     '7u':'F', '8z':'f', 'u2':'H', 'n3':'h', '4e':'O', '1F':'o'}
    elif case == '05B':
        code_d = {'a1':'0', 'U9':'1', 'A5':'2', '0h':'3', 'I6':'i', 'Z7':'p', '0N':'W', 'b3':'w',
                     'p7':'E', 'P6':'e', 'q5':'T', 'O1':'t', 'i1':'S', 'k0':'s', 'd7':'A', 'o8':'a',
                     'V3':'R', 'h2':'r', '7a':'X', 'f0':'x', 'b1':'M', '1S':'m', 'e8':'C', 'M2':'c',
                     's7':'F', '7m':'f', '0J':'H', '0u':'h', 'u1':'O', 'i7':'o'}
    elif case == '06A':
        code_d = {'E3':'0', '2R':'1', 'H8':'2', 'D2':'3', 'P4':'i', '3j':'p', 'U1':'W', '8G':'w',
                     '8x':'E', '6i':'e', '5A':'T', '1d':'t', 'l2':'S', 'F4':'s', 'k3':'A', 'R3':'a',
                     'x7':'R', '8u':'r', 'r8':'X', 'q9':'x', '1y':'M', 'R2':'m', '5y':'C', '1W':'c',
                     'l0':'F', 'B1':'f', 'f6':'H', 't3':'h', '0d':'O', '7C':'o'}
    elif case == '06B':
        code_d = {'3H':'0', 'V9':'1', '9D':'2', 'E6':'3', 'g6':'i', '1h':'p', 'F7':'W', 'V8':'w',
                     '4Z':'E', '7S':'e', 'y8':'T', '9F':'t', 'c2':'S', '9e':'s', '0c':'A', 'k6':'a',
                     'v4':'R', 'G1':'r', 'v5':'X', '1g':'x', 'H3':'M', 'r5':'m', 'q3':'C', 'k1':'c',
                     '6q':'F', '2l':'f', '4t':'H', '2h':'h', '4c':'O', 'I7':'o'}
    elif case == '07A':
        code_d = {'4q':'0', '1I':'1', '8J':'2', '7o':'3', 'G6':'i', 'g2':'p', '0m':'W', '0w':'w',
                     '4I':'E', 'v8':'e', 'p6':'T', '1N':'t', '4X':'S', 'F1':'s', '0q':'A', 'X9':'a',
                     'e1':'R', 'C4':'r', 'S1':'X', '3e':'x', 'c1':'M', 'f3':'m', 'w2':'C', 'o1':'c',
                     '0v':'F', 'i8':'f', 't4':'H', '6l':'h', 'o5':'O', '5k':'o'}
    elif case == '07B':
        code_d = {'X7':'0', '4E':'1', 'b9':'2', 'W6':'3', 'P9':'i', 'y9':'p', 'L8':'W', '0K':'w',
                     '5E':'E', 'P3':'e', '1p':'T', '2G':'t', '2A':'S', '9J':'s', 'd8':'A', '7e':'a',
                     '6S':'R', 'k5':'r', 'n8':'X', 'Y6':'x', 'v6':'M', '1l':'m', '0r':'C', 'j7':'c',
                     '8i':'F', '2r':'f', '1z':'H', 'o4':'h', '4C':'O', '7W':'o'}
    elif case == '08A':
        code_d = {'i6':'0', 'F2':'1', 'L6':'2', '6A':'3', '7s':'i', 'w7':'p', '3D':'W', 'J0':'w',
                     'D5':'E', '5I':'e', '7i':'T', 'F8':'t', '8k':'S', 'c7':'s', 't7':'A', '0V':'a',
                     '2u':'R', 'I4':'r', 'i2':'X', 'M5':'x', '1J':'M', 'X8':'m', 'c6':'C', '2n':'c',
                     '4u':'F', 'u4':'f', 'T8':'H', '9l':'h', '2T':'O', '3O':'o'}
    elif case == '08B':
        code_d = {'3S':'0', '6C':'1', 'r9':'2', '8H':'3', '9i':'i', '3g':'p', 'v0':'W', '4G':'w',
                     '0x':'E', 'n0':'e', 'Z4':'T', 'N6':'t', 'Q7':'S', 'w5':'s', 'V7':'A', 'h8':'a',
                     'A2':'R', 'Z0':'r', '6h':'X', '9j':'x', '9Y':'M', 'q6':'m', '1t':'C', 'Z6':'c',
                     'l6':'F', 'x1':'f', '6n':'H', 'O3':'h', 'x8':'O', '6G':'o'}
    elif case == '09A':
        code_d = {'H1':'0', 's2':'1', 'M6':'2', 'L7':'3', 'c5':'i', 'N8':'p', 'm9':'W', '3X':'w',
                     'j1':'E', 'w8':'e', 'T9':'T', 'N9':'t', '1u':'S', 'f5':'s', 'T4':'A', 'L9':'a',
                     '4H':'R', 'Y3':'r', 'j5':'X', 'D9':'x', '3V':'M', 'y3':'m', 'F3':'C', 'w0':'c',
                     'j8':'F', 's0':'f', 'w4':'H', '4x':'h', 'n4':'O', 'U5':'o'}
    elif case == '09B':
        code_d = {'q8':'0', 'K2':'1', 'n6':'2', 'O5':'3', '5F':'i', 'v7':'p', '8h':'W', 'N4':'w',
                     '6O':'E', '2W':'e', 'N7':'T', '7T':'t', '4R':'S', '1w':'s', '1e':'A', 'W4':'a',
                     '5u':'R', 'L5':'r', '6s':'X', 'o7':'x', 'e2':'M', '8F':'m', '0Z':'C', 'h3':'c',
                     'x2':'F', '2p':'f', '9Q':'H', '7g':'h', '2L':'O', 'J5':'o'}
    elif case == '10A':
        code_d = {'G3':'0', 'G0':'1', '6d':'2', '0b':'3', '8V':'i', 'a2':'p', '9W':'W', '6j':'w',
                     '1K':'E', 'I1':'e', 's6':'T', 'Y0':'t', '9s':'S', '9E':'s', 'M0':'A', '6Z':'a',
                     'e9':'R', 'U3':'r', 'J3':'X', 'm1':'x', '4g':'M', '1q':'m', '5Z':'C', '1m':'c',
                     'r3':'F', '1V':'f', 'm3':'H', 'k8':'h', 'B2':'O', '0g':'o'}
    elif case == '10B':
        code_d = {'w3':'0', 'P2':'1', '6t':'2', 'm6':'3', '2Q':'i', '8C':'p', 'G7':'W', '5h':'w',
                     'i0':'E', '2K':'e', 'g7':'T', '5T':'t', '9G':'S', '2g':'s', '6k':'A', 'O6':'a',
                     'p9':'R', '6y':'r', 'S7':'X', 'Y4':'x', '6b':'M', '6x':'m', '7y':'C', '9u':'c',
                     '0f':'F', '7Z':'f', '9y':'H', 'W7':'h', '8y':'O', 'm8':'o'}
    elif case == '11A':
        code_d = {'B3':'0', '0D':'1', 'k2':'2', '5H':'3', '3W':'i', '2D':'p', '6B':'W', 'E9':'w',
                     'l8':'E', '4p':'e', 'K9':'T', 'f7':'t', '6N':'S', 'z6':'s', '5e':'A', 'D7':'a',
                     'a7':'R', '7Y':'r', 'z2':'X', 'r2':'x', '4N':'M', '3x':'m', 'g3':'C', '0p':'c',
                     'v3':'F', '8f':'f', '6o':'H', 'L4':'h', '0G':'O', 'S5':'o'}
    elif case == '11B':
        code_d = {'y2':'0', 'h4':'1', 'D4':'2', 'K4':'3', '2q':'i', '4L':'p', 'Q8':'W', 'b5':'w',
                     '1a':'E', 'K3':'e', 'O2':'T', '9I':'t', '6v':'S', 'G5':'s', 'W5':'A', '2N':'a',
                     'Q3':'R', 'O7':'r', 'z3':'X', '2P':'x', '6w':'M', 'T3':'m', '3t':'C', '0I':'c',
                     'l3':'F', 'w1':'f', '9p':'H', '4S':'h', 'p8':'O', '4Y':'o'}
    elif case == '12A':
        code_d = {'z9':'0', '0B':'1', 'N2':'2', '2U':'3', '5J':'i', 'n9':'p', 'I2':'W', 'J7':'w',
                     '6T':'E', '4T':'e', '7G':'T', 'd3':'t', 'M1':'S', '5R':'s', '8P':'A', 'Q4':'a',
                     '4w':'R', '7n':'r', '2d':'X', '7b':'x', 'g4':'M', '9f':'m', 'N5':'C', 'i9':'c',
                     '9q':'F', 'r1':'f', '6g':'H', '7t':'h', '4U':'O', 'L2':'o'}
    elif case == '12B':
        code_d = {'8A':'0', '2s':'1', 'W8':'2', 'D3':'3', 'a6':'i', 'B5':'p', 'J1':'W', '8j':'w',
                     '6P':'E', 'C7':'e', '8Z':'T', 'R1':'t', '5G':'S', '0C':'s', 'P5':'A', 'V6':'a',
                     '3K':'R', '1R':'r', 'W2':'X', 'Z9':'x', '8n':'M', '1f':'m', '9v':'C', 'q1':'c',
                     '5q':'F', 'g8':'f', 'c3':'H', 'T5':'h', '8N':'O', 'A8':'o'}
    elif case == '13A':
        code_d = {'4A':'0', 'C9':'1', 'T6':'2', '5B':'3', 'C3':'i', 'P7':'p', 'k7':'W', 'Y9':'w',
                     '2Z':'E', 'Q6':'e', 'Z1':'T', 'p4':'t', 't6':'S', '2X':'s', '6z':'A', '7d':'a',
                     '0M':'R', '8v':'r', '9M':'X', '8T':'x', 'x9':'M', 'j3':'m', 'j6':'C', '0t':'c',
                     'e7':'F', 'h5':'f', '8b':'H', 'k4':'h', '7j':'O', 'W3':'o'}
    elif case == '13B':
        code_d = {'5g':'0', 'z0':'1', '9O':'2', '0F':'3', '5C':'i', '3C':'p', 't5':'W', '3L':'w',
                     '6M':'E', 'y5':'e', '7X':'T', 'm7':'t', '2Y':'S', '9r':'s', '7I':'A', '9o':'a',
                     '4b':'R', '8q':'r', '9U':'X', '2z':'x', 'u9':'M', '9N':'m', '3d':'C', '4M':'c',
                     '3k':'F', '9t':'f', '6r':'H', '5w':'h', '0A':'O', '0S':'o'}
    elif case == '14A':
        code_d = {'Z3':'0', '7E':'1', 'D6':'2', '1j':'3', '0W':'i', 'd0':'p', '3P':'W', '6E':'w',
                     'X2':'E', '5U':'e', '2j':'T', '2E':'t', 'z5':'S', 'y6':'s', 'X5':'A', '4z':'a',
                     '3h':'R', 'X4':'r', 'o6':'X', 'E5':'x', '7w':'M', 'y1':'m', '0j':'C', '1n':'c',
                     '5S':'F', 'W9':'f', 'e5':'H', '6a':'h', 'j2':'O', 'J6':'o'}
    elif case == '14B':
        code_d = {'f8':'0', '4B':'1', '4W':'2', '8B':'3', 'd4':'i', '8d':'p', '6J':'W', 'J9':'w',
                     '3N':'E', '1P':'e', '5O':'T', 'f1':'t', '2O':'S', '3U':'s', '5N':'A', '1E':'a',
                     '4s':'R', '8a':'r', '1Q':'X', '5r':'x', 'x0':'M', '8m':'m', 'v9':'C', 'j4':'c',
                     '1U':'F', 'x5':'f', 'M4':'H', '3Z':'h', '1G':'O', '1o':'o'}
    elif case == '15A':
        code_d = {'C8':'0', '7F':'1', 'a0':'2', '5Q':'3', '3J':'i', 'E7':'p', 'R9':'W', 'A4':'w',
                     '5c':'E', '3G':'e', '4l':'T', 'h9':'t', '7c':'S', 'm4':'s', '6H':'A', 'A6':'a',
                     'M3':'R', 'N0':'r', '6Y':'X', '5m':'x', '8g':'M', 'U2':'m', 'V5':'C', '3s':'c',
                     'U0':'F', 'e6':'f', '7q':'H', 'F0':'h', 'b6':'O', '7K':'o'}
    elif case == '15B':
        code_d = {'P1':'0', '2J':'1', 'B9':'2', '2v':'3', 'R0':'i', 'G8':'p', '8X':'W', '3n':'w',
                     '4K':'E', '1X':'e', '9w':'T', 'K1':'t', '1Z':'S', 'P8':'s', '0Y':'A', '3R':'a',
                     '1k':'R', 'V1':'r', 'Y8':'X', 'R6':'x', 'x4':'M', '6R':'m', 'c0':'C', '7v':'c',
                     'g1':'F', 't0':'f', '1C':'H', '3m':'h', 'o9':'O', '8D':'o'}
    elif case == '16A':
        code_d = {'t1':'0', '8M':'1', 'K0':'2', 'X1':'3', '9T':'i', '2H':'p', '0O':'W', '4n':'w',
                     'h0':'E', '3b':'e', '2x':'T', 'M7':'t', '1T':'S', 'n5':'s', 'n2':'A', 'R7':'a',
                     '0e':'R', 'b2':'r', '3y':'X', 'u8':'x', '7R':'M', '0Q':'m', '9k':'C', 'y7':'c',
                     'C2':'F', '8Y':'f', '6W':'H', 'q7':'h', '4f':'O', '8w':'o'}
    elif case == '16B':
        code_d = {'F5':'0', 'C5':'1', 'R8':'2', '8s':'3', 'L0':'i', '7D':'p', '0n':'W', '3I':'w',
                     '3M':'E', '5l':'e', '9P':'T', 'K7':'t', '8S':'S', '4O':'s', 'H2':'A', 'r0':'a',
                     '4k':'R', '2m':'r', '9z':'X', '5V':'x', 'z1':'M', '4i':'m', '7k':'C', 'n1':'c',
                     'H6':'F', 'T1':'f', 'Z5':'H', '9m':'h', '1c':'O', '2S':'o'}
    elif case == '17A':
        code_d = {'A9':'0', '4D':'1', 'c8':'2', '1B':'3', 'H5':'i', '7B':'p', '7f':'W', '4Q':'w',
                     '9Z':'E', 'd6':'e', 'C0':'T', 'R5':'t', 'p5':'S', 'S0':'s', 'I0':'A', '8R':'a',
                     'k9':'R', '6X':'r', 'A0':'X', '4h':'x', 'Q0':'M', 'Z8':'m', 's9':'C', '2e':'c',
                     'i3':'F', 'B6':'f', '8W':'H', 'q2':'h', 'n7':'O', 'O0':'o'}
    elif case == '17B':
        code_d = {'3F':'0', 'E8':'1', '2o':'2', '4d':'3', '7O':'i', 'J8':'p', 'd2':'W', 'o0':'w',
                     '6I':'E', 'b8':'e', '3Y':'T', 'I9':'t', '5X':'S', 'T0':'s', 'Q1':'A', '2t':'a',
                     '7U':'R', '9c':'r', 'u0':'X', '5f':'x', '0X':'M', 'Z2':'m', '9d':'C', '5P':'c',
                     '2y':'F', '4a':'f', 'B8':'H', '7V':'h', 'A3':'O', '0E':'o'}
    else:
        # no progress code dictionary for that case
        case = 'Z'
        code = 'Z'
    
    if case != 'Z':
        inv_code_d = {ii: jj for jj, ii in code_d.items()}
#### DE-CODE Progress Code into Click #################################################################
# also check that submitted Progress Code is valid (session numbers, click/button order)
# click = session/button unlock/clicks decoded (no duplicates, first click only)
# 0 = 1st session, E = Emerald button unlock, e = emerald button click
# code = submitted progress code to continue session
def CodetoClick():
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d     
    click = ''
    
    if code == '':
        #first session
        click = '0'
        code = inv_code_d['0'] 
    elif len(code)%2 == 0:
        #even number
        for ii in range(int(len(code)/2)):
            jj = code_d.get(code[2*ii:2*ii+2])
            if jj != None:
                click = click + jj
            else:
                # error, key not found
                click = click + 'Z'
        
        if click.find('Z') != -1:
            # invalid code
            click = 'Z'
        else:
            # valid codes, update click with session number
            # check for session numbers and in order
            s3 = click.find('3')
            s2 = click.find('2')
            s1 = click.find('1')
            s0 = click.find('0')          
            
            if s3 != -1 and s2 != -1 and s1 != -1 and s0 != -1:
                # highest session to keep track of, don't update code with new number
                if s0 < s1 and s1 < s2 and s2 < s3:
                    # correct order, do nothing
                    click
                else:
                    click = 'Z'
            elif s3 == -1 and s2 != -1 and s1 != -1 and s0 != -1:
                if s0 < s1 and s1 < s2:
                    click = click + '3'
                    code = code + inv_code_d['3']
                else:
                    click = 'Z'
            elif s3 == -1 and s2 == -1 and s1 != -1 and s0 != -1:
                if s0 < s1:
                    click = click + '2'
                    code = code + inv_code_d['2']
                else:
                    click = 'Z'
            elif s3 == -1 and s2 == -1 and s1 == -1 and s0 != -1:
                if s0 == 0:
                    click = click + '1'
                    code = code + inv_code_d['1']
                else:
                    click = 'Z'
            else:
                click = 'Z'

    else:
        # not even number
        click = 'Z'
      
    # Further check click
    if click != 'Z' and case !='Z':
        # check for duplicates
        for ii in range(len(click)):
            if click.find(click[ii]) != ii:
                code = 'Z' # duplicate
        
        # check order of buttons and clicks
        for ii in case_d:
            if click.find(ii) != -1:
                if click.find(case_d[ii]) == -1 or click.find(ii) < click.find(case_d[ii]):
                    code = 'Z' # error
#### ENABLE BUTTONS #################################################################################
# I = Initial Report Filing
# P = Patient Information -- J, H, C or M (color/image changes)
# W = Patient Interview -- J, H, C or M (color/image changes)
# E = Emerald, T = Topaz, S = Sapphire, A = Amethyst, R = Ruby -- Witness Interviews
# X = Xray, M = Medical Record, C = Camera Footage, F = Footprints 

def evidencebuttons(l):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    layout = widgets.Layout(width='90px')
    #####--------------------------------------------------------------------------------
    if l.isalpha() and l.isupper(): # ignore clicks & session number when initializing new session
    #---#--------------------------------------------------------------------------------
        if l == 'I': 
            I.description="Report"
            I.style={'font_weight':'bold','button_color':'#D3D3D3'}
            I.layout = layout
            I_i.value = open("I.png", "rb").read()
            I.disabled=False
    #--------------------------------------   
        elif l == 'P':
            P.description="Patient"
            P.disabled=False
            if patient_d[case[0:2]][0]=='J': # Jane
                P.style = {'button_color':'#F7A6A0','font_weight':'bold'}
                P.layout = layout
                P_i.value = open("PJ.png", "rb").read()
            elif patient_d[case[0:2]][0]=='H': # Henry
                P.style = {'button_color':'#94BFAB','font_weight':'bold'}
                P_i.value = open("PH.png", "rb").read()
            elif patient_d[case[0:2]][0]=='C': # Cynthia
                P.style = {'button_color':'#FAB190','font_weight':'bold'}
                P_i.value = open("PC.png", "rb").read()
            elif patient_d[case[0:2]][0]=='M': # Michael
                P.style = {'button_color':'#FFDD9C','font_weight':'bold'}
                P_i.value=open("PM.png", "rb").read()
    #--------------------------------------
        elif l == 'W':
            W.disabled=False
            W.layout = layout
            if patient_d[case[0:2]][0]=='J': # Jane
                W.style = {'button_color':'#F7A6A0','font_weight':'bold'}
                W_i.value = open("PJ.png", "rb").read()
                W.description="Jane"
            elif patient_d[case[0:2]][0]=='H': # Henry
                W.style = {'button_color':'#94BFAB','font_weight':'bold'}
                W_i.value = open("PH.png", "rb").read()
                W.description="Henry"
            elif patient_d[case[0:2]][0]=='C': # Cynthia
                W.style = {'button_color':'#FAB190','font_weight':'bold'}
                W_i.value = open("PC.png", "rb").read()
                W.description="Cynthia"
            elif patient_d[case[0:2]][0]=='M': # Michael
                W.style = {'button_color':'#FFDD9C','font_weight':'bold'}
                W_i.value=open("PM.png", "rb").read()
                W.description="Michael"
    #--------------------------------------    
        elif l == 'E':
            E.description="Emerald"
            E.style={'button_color':'#8BA09D','font_weight':'bold'}
            E.layout = layout
            E_i.value = open("E.png", "rb").read()
            E.disabled = False
    #--------------------------------------
        elif l == 'T':
            T.description="Topaz"
            T.style={'button_color':'#DABA88','font_weight':'bold'}
            T.layout = layout
            T_i.value = open("T.png", "rb").read()
            T.disabled = False 
    #--------------------------------------
        elif l == 'S':
            S.description="Sapphire"
            S.style={'button_color':'#8589B2','font_weight':'bold'}
            S.layout = layout
            S_i.value = open("S.png", "rb").read()
            S.disabled = False
    #--------------------------------------
        elif l == 'A':
            A.description="Amethyst"
            A.style={'button_color':'#BB8CAB','font_weight':'bold'}
            A.layout = layout
            A_i.value = open("A.png", "rb").read()
            A.disabled = False
    #--------------------------------------
        elif l == 'R':
            R.description="Ruby"
            R.style={'button_color':'#BA8178','font_weight':'bold'}
            R.layout = layout
            R_i.value = open("R.png", "rb").read()
            R.disabled = False 
    #--------------------------------------
        elif l == 'X':
            X.description="X-Ray"
            X.style={'button_color':'#D3D3D3','font_weight':'bold'}
            X.layout = layout
            X_i.value = open("X.png", "rb").read()
            X.disabled=False
    #--------------------------------------
        elif l == 'M':
            M.description="Medical"
            M.style={'button_color':'#D3D3D3','font_weight':'bold'}
            M.layout = layout
            M_i.value = open("M.png", "rb").read()
            M.disabled=False
    #--------------------------------------
        elif l == 'C':
            C.description="Camera"
            C.style={'button_color':'#D3D3D3','font_weight':'bold'}
            C.layout = layout
            C_i.value = open("C.png", "rb").read()
            C.disabled=False
    #--------------------------------------
        elif l == 'F':
            F.description="Footprints"
            F.style={'button_color':'#D3D3D3','font_weight':'bold'}
            F.layout = layout
            F_i.value = open("F.png", "rb").read()
            F.disabled=False    
    #--------------------------------------
        elif l == 'H':
            H.description="Heights"
            H.layout = layout
            H.style={'button_color':'#D3D3D3','font_weight':'bold'}
            H_i.value = open("H.png", "rb").read()
            H.disabled=False 
    #--------------------------------------
        elif l == 'O':
            O.description="Shoes"
            O.style={'button_color':'#D3D3D3','font_weight':'bold'}
            O.layout = layout
            O_i.value = open("O.png", "rb").read()
            O.disabled=False 
    #---#--------------------------------------------------------------------------------
        if l != 'I' and l != 'P':
            # I & P always enabled from the start, don't keep track of in click
            #---Check click for duplicate, update code 
            if click.find(l) == -1:
                # new button enabled
                click = click + l
                code = code + inv_code_d[l]
######## EVIDENCE for each CASE ################################################################
# organized by case number
# the information that appears on the right side after a button is clicked
# i = Initial Report Filing
# p = Patient Information
# w = Patient Interview 
# e = Emerald, t = Topaz, s = Sapphire, a = Amethyst, r = Ruby -- Witness Interviews
# x = Xray, m = Medical Record, c = Camera Footage, f = Footprints 
def updateevidence(l):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
## Vertical Spacing for title
    vspace = "<br>"
## Intitial Report  
    I_title = vspace + "<b>Intial Report</b>"
    I_text = "Please closely review the following information collected regarding Case #" + ID + "<br>"
    interview_list = "<b>List of Witnesses:</b> <i> Action: Interview + Text: [Name] </i><br>\
                                                        <ul> <li>A. Amethyst</li>\
                                                        <li>E. Emerald</li>\
                                                        <li>R. Ruby</li>\
                                                        <li>S. Sapphire</li>\
                                                        <li>T. Topaz</li> </ul>"
    request_xray = "<b>View X-ray of the Injury:</b> <i> Action: Request + Text: X-ray </i><br>"
## Patient Info    
    P_title = vspace + "<b>Patient Information</b>"
    P_text = "Please review the following information collected regarding the patient<br>"
    PJ_add = ""
    PH_add = ""
    PC_add = ""
    PM_add = ""
## Interviews
    W_title = vspace + "<b>Patient Interview</b>"
    W_text = "Please review the following summary of the interview with the patient <br>"
    E_title = vspace + "<b>Interview E. Emerald</b>"
    E_text = "Please review the following summary of the interview with Dr. Emerald <br>"
    E_add = "<br><b>Address:</b> 300 East 6th Street, West Lansing, MI"
    T_title = vspace + "<b>Interview T. Topaz</b>"
    T_text = "Please review the following summary of the interview with Mrs. Topaz <br>"
    T_add = "<br><b>Address:</b> 115 Main Street, Apartment 5, West Lansing, MI"
    S_title = vspace + "<b>Interview S. Sapphire</b>"
    S_text = "Please review the following summary of the interview with Mr. Sapphire <br>"
    S_add = "<br><b>Address:</b> 115 Main Street, Apartment 1, West Lansing, MI"
    A_title = vspace + "<b>Interview A. Amethyst</b>"
    A_text = "Please review the following summary of the interview with Prof. Amethyst <br>"
    A_add = "<br><b>Address:</b> 428 South Shaw Lane, West Lansing, MI"
    R_title = vspace + "<b>Interview R. Ruby</b>"
    R_text = "Please review the following summary of the interview with Mr. Ruby <br>"
    R_add = "<br><b>Address:</b> 118 Main Street, Apartment A, West Lansing, MI"
## X-Ray           
    X_title = vspace + "<b>Injury X-Ray</b>"
    X_text = "Please review the x-ray from the patient’s hospital visit<br>" 
    X_dir = "Additional medical records will be available once the injury has been identified.<br>\
            <i> Action: Injury + Text: [Fracture Name] </i>" # next directions
## Medical           
    M_title = vspace + "<b>Medical Record</b>"
    M_text = "Please review the medical record from the patient’s hospital visit<br>" 
    M_dir = "A patient interview was located at the hospital.<br>\
            <i> Action: Interview + Text: [Name] </i>" # next directions
## Camera           
    C_title = vspace + "<b>Medical Record</b>"
    C_text = "Please review the collected security camera footage from the day of the incident<br>" 
    C_dir = "Heights of the witnesses were measured during the interviews<br>\
            <i> Action: Request + Text: Heights </i>" # next directions
## Footprints          
    F_title = vspace + "<b>Footprints</b>"
    F_text = "Please review the footprint measurements from the location of the incident<br>" 
    F_dir = "Shoe sizes of the witnesses were recorded during the interviews<br>\
            <i> Action: Request + Text: Shoe Sizes </i>" # next directions
## Heights          
    H_title = vspace + "<b>Heights of Witnesses</b>"
    H_text = "Please review the heights of the witnesses that were measured during the interviews<br>" 
## Shoe Sizes         
    O_title = vspace + "<b>Shoe Sizes of Witnesses</b>"
    O_text = "Please review the shoe sizes of the witnesses that were recorded during the interviews<br>"
#######
#HTML code to embed YOUTUBE video    
# "<iframe width='560' height='315'\
                #src='https://www.youtube-nocookie.com/embed/S5Vz-z4PEkk?start=33&modestbranding=1&autoplay=0&rel=0'\
                #frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                #allowfullscreen></iframe>"

####### MULTIPLE CASES #######-----------------------------------------------------------------------#######
#---#---------------------------------------------------
    if l == 'p': # Patient Information
        textbox_title.value = P_title
        textbox_top.value = P_text
        if patient_d[case[0:2]][0]=='J': # Jane
            textbox_middle.value = "<br><b>Patient Name:</b> Jane\
                  <br><b>Age:</b> 75 years old\
                  <br><b>Sex:</b> Female\
                  <br><b>Height:</b> 1.5 m\
                  <br><b>Weight:</b> 50 kg\
                  <br><b>Profession:</b> Retired Secretary"
            textbox_bottom.value = PJ_add # address
        elif patient_d[case[0:2]][0]=='H': # Henry
            textbox_middle.value = "<br><b>Patient Name:</b> Henry\
                  <br><b>Age:</b> 83 years old\
                  <br><b>Sex:</b> Male\
                  <br><b>Height:</b> 1.65 m\
                  <br><b>Weight:</b> 64 kg\
                  <br><b>Profession:</b> Retired Professor"
            textbox_bottom.value = PH_add
        elif patient_d[case[0:2]][0]=='C': # Cynthia
            textbox_middle.value = "<br><b>Patient Name:</b> Cynthia\
                  <br><b>Age:</b> 23 years old\
                  <br><b>Sex:</b> Female\
                  <br><b>Height:</b> 1.7 m\
                  <br><b>Weight:</b> 64 kg\
                  <br><b>Profession:</b> Gradaute Student"
            textbox_bottom.value = PC_add # address
        elif patient_d[case[0:2]][0]=='M': # Michael
            textbox_middle.value = "<br><b>Patient Name:</b> Michael\
                  <br><b>Age:</b> 22 years old\
                  <br><b>Sex:</b> Male\
                  <br><b>Height:</b> 1.83 m\
                  <br><b>Weight:</b> 82 kg\
                  <br><b>Profession:</b> Gradaute Student" 
            textbox_bottom.value = PM_add # address
#---#---------------------------------------------------
    elif l == 'x': # X-Ray    
        textbox_title.value = X_title
        textbox_top.value = X_text
        textbox_bottom.value = X_dir
        if patient_d[case[0:2]][1]=='j': # jaw
            textbox_middle.value = "JAW"
        elif patient_d[case[0:2]][1]=='w': # wrist
            textbox_middle.value = "WRIST"
        elif patient_d[case[0:2]][1]=='e': # elbow
            textbox_middle.value = "ELBOW"
        elif patient_d[case[0:2]][1]=='h': # hip
            textbox_middle.value = "HIP"
#---#---------------------------------------------------
    elif l == 'm': # Medical Record
        textbox_title.value = M_title
        textbox_top.value = M_text
        textbox_bottom.value = M_dir
        if patient_d[case[0:2]]=='JwO': # Jane Wrist Outdoors
            textbox_middle.value = "<br><b>Patient Name:</b> Jane, <b>Date of Birth:</b> November 19th\
                  <br><b>Sex:</b> Female, <b>Height:</b> 1.5 m, <b>Weight:</b> 50 kg\
                  <br><b>Emergency Room Admission:</b> March 1st\
                  <br> 75-yo woman brought in by ambulance after a fall outdoors.\
                  Pain and obvious angulation of L wrist.\
                  X-ray confirmed fracture of distal radius (Colles’ fracture).\
                  Referred to orthopaedic surgery for internal plating.\
                  <br><b>View Complete Medical Record: </b>\
                  <a href='https://drive.google.com/file/d/1E-2qvEGCbAy_29wmtk3UUM3dE2dbFOeg'\
                  target='_blank'>https://drive.google.com/file/d/1E-2qvEGCbAy_29wmtk3UUM3dE2dbFOeg</a>"

        elif patient_d[case[0:2]]=='JwI': # Jane Wrist Indoors
            textbox_middle.value = "Jane Wrist Indoors"
        elif patient_d[case[0:2]]=='HwO': # Henry Wrist Outdoors
            textbox_middle.value = "<br><b>Patient Name:</b> Henry, <b>Date of Birth:</b> February 12th\
                  <br><b>Sex:</b> Male, <b>Height:</b> 1.65 m, <b>Weight:</b> 64 kg\
                  <br><b>Emergency Room Admission:</b> February 15th\
                  <br> 83-yo male brought in by ambulance after a fall outdoors.\
                  Pain and obvious angulation of left wrist.\
                  X-ray confirmed fracture of distal radius (Colles’ fracture).\
                  Referred to orthopaedic surgery for internal plating.\
                  <br><b>View Complete Medical Record: </b>\
                  <a href='https://drive.google.com/file/d/1487l5wyfr07FHwv4Ik9jnBsCQLpw1PJe'\
                  target='_blank'>https://drive.google.com/file/d/1487l5wyfr07FHwv4Ik9jnBsCQLpw1PJe</a>"
        elif patient_d[case[0:2]]=='HwI': # Henry Wrist Indoors
            textbox_middle.value="Henry Wrist Indoors"
        elif patient_d[case[0:2]]=='CjO': # Cynthia Jaw Outdoors
            textbox_middle.value="Cynthia Jaw Outdoors"
        elif patient_d[case[0:2]]=='CeO': # Cynthia Elbow Outdoors
            textbox_middle.value="<br><b>Patient Name:</b> Cynthia, <b>Date of Birth:</b> June 27th\
                  <br><b>Sex:</b> Female, <b>Height:</b> 1.7 m, <b>Weight:</b> 64 kg\
                  <br><b>Emergency Room Admission:</b> April 4th\
                  <br> 23-yo female brought in by ambulance after a fall outdoors.\
                  Significant pain in right arm, focused around elbow.\
                  X-ray confirmed olecranon fracture with displacement of the fragment.\
                  Transferred to orthopaedic surgery for surgical repair.\
                  Opted for internal plating with screws and tension wires to support bony fragment.\
                  Splint applied.\
                  <br><b>View Complete Medical Record: </b>\
                  <a href='https://drive.google.com/file/d/1l0AWFZAP7kojMr4QgbJzgHCN-r0bT8qk'\
                  target='_blank'>https://drive.google.com/file/d/1l0AWFZAP7kojMr4QgbJzgHCN-r0bT8qk</a>"
        elif patient_d[case[0:2]]=='MjO': # Michael Jaw Outdoors
            textbox_middle.value="Michael Jaw Outdoors"
        elif patient_d[case[0:2]]=='MeO': # Michael Elbow Outdoors
            textbox_middle.value="<br><b>Patient Name:</b> Michael, <b>Date of Birth:</b> February 12th\
                  <br><b>Sex:</b> Male, <b>Height:</b> 1.83 m, <b>Weight:</b> 82 kg\
                  <br><b>Emergency Room Admission:</b> March 30th\
                  <br> 22-yo male brought in by ambulance after a fall outdoors.\
                  Significant pain in right arm, focused around elbow.\
                  X-ray confirmed olecranon fracture with displacement of the fragment.\
                  Transferred to orthopaedic surgery for surgical repair.\
                  Opted for internal plating with screws and tension wires to support bony fragment.\
                  Splint applied.\
                  <br><b>View Complete Medical Record: </b>\
                  <a href='https://drive.google.com/file/d/1ONa1j8V_ehvG0ANxQ7e7GdUDPb8lFhzp'\
                  target='_blank'>https://drive.google.com/file/d/1ONa1j8V_ehvG0ANxQ7e7GdUDPb8lFhzp</a>" 
#---#---------------------------------------------------    
    elif l == 'h': # Heights
        textbox_title.value = H_title
        textbox_top.value = H_text
        textbox_middle.value = "<br><ul><li>A. Amethyst, 1.60 m </li>\
                                        <li>E. Emerald, 1.80 m </li>\
                                        <li>R. Ruby, 1.88 m </li>\
                                        <li>S. Sapphire, 1.91 m </li>\
                                        <li>T. Topaz, 1.70 m </li> </ul>"
        textbox_bottom.value = ""
#---#---------------------------------------------------
    elif l == 'o': # Shoes
        textbox_title.value = O_title
        textbox_top.value = O_text
        textbox_middle.value = "<br><ul><li>A. Amethyst, US W 8.0 </li>\
                                        <li>E. Emerald, US M 10.5 </li>\
                                        <li>R. Ruby, US M 10.0 </li>\
                                        <li>S. Sapphire, US M 11.5 </li>\
                                        <li>T. Topaz, US W 8.5 </li> </ul>"
        textbox_bottom.value = ""

####### CASE-SPECIFIC #######-----------------------------------------------------------------------#######
####### CASE 01 #######-------------------------------------------------------------------------------------#######
    elif case[0:2] == '01':
        if l == 'i': # Initial Report
            textbox_title.value = I_title
            textbox_top.value = I_text
            textbox_middle.value = "<br><b>Date of Incident:</b> March 1st <br>\
                                    <b>Location of Incident:</b> 115 Main Street, West Lansing, MI<br>"\
                                    + interview_list + request_xray
            textbox_bottom.value= ""
        elif l == 'w': # Patient Interview
            textbox_title.value = W_title
            textbox_top.value = W_text
            textbox_middle.value="<br><ul><li>Memory of the event is fuzzy due to shock of injury</li>\
                                    <li>Walking down Main Street on the way to the store</li>\
                                    <li>Was fine and then just suddenly got icy</li>\
                                    <li>Slipped and fell</li>\
                                    <li>Remembers a kind doctor coming over to help and then the paramedics</li></ul>"
            textbox_bottom.value = PJ_add
        elif l == 'e': # Dr. Emerald
            textbox_title.value = E_title
            textbox_top.value = E_text
            textbox_middle.value = "<br><ul><li>Driving down Main Street on the way to his office<\li>\
                                        <li>Saw a woman on the sidewalk</li>\
                                        <li>Called 911 and provided immediate first aid</li>\
                                        <li>Was fine and then just suddenly got icy</li>\
                                        <li>Frozen <i>footprints</i> were in the snow near her</li></ul>"
            textbox_bottom.value = E_add 
        elif l == 't': # Mrs. Topaz
            textbox_title.value = T_title
            textbox_top.value = T_text
            textbox_middle.value = "<br><ul><li>Heard the scream from her apartment</li>\
                                        <li>The steps and sidewalk are supposed to be cleared and salted\
                                            by building management</li>\
                                        <li>She had slipped earlier in the day and mentioned it\
                                            to the supervisor</li></ul>"
            textbox_bottom.value = T_add
        elif l == 's': # Mr. Sapphire
            textbox_title.value = S_title
            textbox_top.value = S_text
            textbox_middle.value = "<br><ul><li>Building supervisor for 115</li>\
                                        <li>Was inside his apartment when the woman fell</li>\
                                        <li>It had been snowing and sleeting for 12 hours</li>\
                                        <li>Many people were walking by that morning</li></ul>"
            textbox_bottom.value = S_add
        elif l == 'a': # Prof. Amethyst
            textbox_title.value = A_title
            textbox_top.value = A_text
            textbox_middle.value = "<br><ul><li>On a snowshoe hike through the snow</li>\
                                        <li>Main Street is part of her normal walking route</li>\
                                        <li>Heard a scream behind her</li>\
                                        <li>Turned and saw a woman in pink on the ground</li></ul>"
            textbox_bottom.value = A_add
        elif l == 'r': # Mr. Ruby
            textbox_title.value = R_title
            textbox_top.value = R_text
            textbox_middle.value = "<br><ul><li>Was looking out the window at the new snow and ice on the ground</li>\
                                        <li>Sun had just come out </li>\
                                        <li>Most of the sidewalk had been cleared, a spot in front of 115\
                                                was only partially cleared </li>\
                                        <li>Saw an older woman slip on the ice</li>\
                                        <li>Has a <i>security camera</i> that is focused on the street</li></ul>"
            textbox_bottom.value = R_add
        elif l == 'c': # Security Camera
            textbox_title.value = C_title
            textbox_top.value = C_text
            textbox_middle.value = ""
            textbox_bottom.value = C_dir
        elif l == 'f': # Footprints
            textbox_title.value = F_title
            textbox_top.value = F_text
            textbox_middle.value = ""
            textbox_bottom.value = F_dir
####### CASE 06 #######-------------------------------------------------------------------------------------#######
    elif case[0:2] == '06':
        if l == 'i': # Initial Report
            textbox_title.value = I_title
            textbox_top.value = I_text
            textbox_middle.value = "<b>Date of Incident:</b> February 15th <br>\
                                    <b>Location of Incident:</b> 115 Main Street, West Lansing, MI<br>"\
                                    + interview_list + request_xray
            textbox_bottom.value=""
        elif l == 'w': # Patient Interview
            textbox_title.value = W_title
            textbox_top.value = W_text
            textbox_middle.value="<br><ul><li>Memory of the event is fuzzy due to shock of injury\
                                    and the anesthesia of the surgery</li>\
                                    <li>Walking down Main Street on the way to see a friend</li>\
                                    <li>Slipped and fell when he was startled</li>\
                                    <li>Doesn’t remember what startled him</li>\
                                    <li>Remembers a kind doctor coming over to help and then the paramedics</li></ul>"
            textbox_bottom.value = PH_add
        elif l == 'e': # Dr. Emerald
            textbox_title.value = E_title
            textbox_top.value = E_text
            textbox_middle.value = "<br><ul><li>Driving down Main Street on the way to his office</li>\
                                        <li>Saw a man on the sidewalk</li>\
                                        <li>Called 911 and provided immediate first aid</li>\
                                        <li>Didn't see why he fell</li></ul>"
            textbox_bottom.value = E_add 
        elif l == 't': # Mrs. Topaz
            textbox_title.value = T_title
            textbox_top.value = T_text
            textbox_middle.value="<br><ul><li>Heard screech of tires and car horn</li>\
                                        <li>Heard a screen from her apartment</li>\
                                        <li>Went down to see what had happened</li>\
                                        <li>Saw <i>footprints</i> in the snow ardoun the poor genetleman</li></ul>"
            textbox_bottom.value = T_add
        elif l == 's': # Mr. Sapphire
            textbox_title.value = S_title
            textbox_top.value = S_text
            textbox_middle.value="<br><ul><li>Lives in ground floor of apartment building</li>\
                                        <li>Was inside his apartment when the man fell</li>\
                                        <li>It was snowing all day and didn’t want to go out</li>\
                                        <li>Heard a car horn, looked out the window and saw a man on the ground<\li>\
                                        <li>Not many people out today due to the snow</li></ul>"
            textbox_bottom.value = S_add
        elif l == 'a': # Prof. Amethyst
            textbox_title.value = A_title
            textbox_top.value = A_text
            textbox_middle.value="<br><ul><li>On a snowshoe hike through the snow with her dog</li>\
                                        <li>Main Street is part of her normal walking route</li>\
                                        <li>Heard a scream across the street</li>\
                                        <li>Turned and saw a man in green on the ground</li></ul>"
            textbox_bottom.value = A_add
        elif l == 'r': # Mr. Ruby
            textbox_title.value = R_title
            textbox_top.value = R_text
            textbox_middle.value="<br><ul><li>Was looking out the window at the new snow and ice on the ground</li>\
                                        <li>Sun had just come out </li>\
                                        <li>Saw a silver car driving down the street </li>\
                                        <li>The car honked its horn when a dog ran across the street<li>\
                                        <li>Saw an older man slip on the ice</li>\
                                        <li>Has a <i>security camera</i> that he thinks\
                                        is focused on the street</li></ul>"
            textbox_bottom.value = R_add
        elif l == 'c': # Security Camera
            textbox_title.value = C_title
            textbox_top.value = C_text
            textbox_middle.value = ""
            textbox_bottom.value = C_dir
        elif l == 'f': # Footprints
            textbox_title.value = F_title
            textbox_top.value = F_text
            textbox_middle.value = ""
            textbox_bottom.value = F_dir   
####### CASE 12 #######-------------------------------------------------------------------------------------#######
    elif case[0:2] == '12':
        if l == 'i': # Initial Report
            textbox_title.value = I_title
            textbox_top.value = I_text
            textbox_middle.value = "<br><b>Date of Incident:</b> April 4th <br>\
                                    <br><b>Location of Incident:</b> 115 Main Street, West Lansing, MI<br>"\
                                    + interview_list + request_xray
            textbox_bottom.value=""
        elif l == 'w': # Patient Interview
            textbox_title.value = W_title
            textbox_top.value = W_text
            textbox_middle.value="<br><ul><li>Was out on Main Street rollerblading</li>\
                                    <li>Someone yelled at her about making way for pedestrians</li>\
                                    <li>All of a sudden, found herself on the ground</li>\
                                    <li>Not sure what tripped her</li></ul>"
            textbox_bottom.value = PC_add
        elif l == 'e': # Dr. Emerald
            textbox_title.value = E_title
            textbox_top.value = E_text
            textbox_middle.value = "<br><ul><li>Driving down Main Street on the way back from his office</li>\
                                        <li>Saw a woman in orange lying on the ground</li>\
                                        <li>Saw someone stomp off around the corner</li>\
                                        <li>Called 911 and provided immediate first aid</li></ul>"
            textbox_bottom.value = E_add
        elif l == 't': # Mrs. Topaz
            textbox_title.value = T_title
            textbox_top.value = T_text
            textbox_middle.value="<br><ul><li>Her apartment is on the upper floor </li>\
                                        <li>Not a good view of the street with her eyesight<li>\
                                        <li>Heard a person yelling about annoying roller skaters<li>\
                                        <li>Then heard a crash and a scream</li></ul>"
            textbox_bottom.value = T_add
        elif l == 's': # Mr. Sapphire
            textbox_title.value = S_title
            textbox_top.value = S_text
            textbox_middle.value="<br><ul><li>Hosting a board game night</li>\
                                        <li>Went out to get some more snacks </li>\
                                        <li>Heard a scream in the distance behind him<li>\
                                        <li>But was focused on getting to the store<li>\
                                        <li>Why limping? His foot has been bothering him\
                                        for a while now, thanks for asking</li></ul>"
            textbox_bottom.value = S_add
        elif l == 'a': # Prof. Amethyst
            textbox_title.value = A_title
            textbox_top.value = A_text
            textbox_middle.value="<br><ul><li>Had just walked to Main Street to visit a good friend\
                                        for an evening of board games </li>\
                                        <li>Her friend went out to buy more snacks </li>\
                                        <li>A little while later heard yelling and a scream<li>\
                                        <li>Ran out and saw a young woman on the ground</li></ul>"
            textbox_bottom.value = A_add
        elif l == 'r': # Mr. Ruby
            textbox_title.value = R_title
            textbox_top.value = R_text
            textbox_middle.value="<br><ul><li>Was looking out the window at the sunset</li>\
                                        <li>Saw someone from across the street head out of\
                                        their apartment, they looked upset </li>\
                                        <li>Saw a woman rollerblading<li>\
                                        <li>Didn't hear anything, had music turnd up loudly</li>\
                                        <li>Has a <i>security camera</i> pointed at the street</li></ul>"
            textbox_bottom.value = R_add
        elif l == 'c': # Security Camera
            textbox_title.value = C_title
            textbox_top.value = C_text
            textbox_middle.value = ""
            textbox_bottom.value = C_dir
        elif l == 'f': # Footprints
            textbox_title.value = F_title
            textbox_top.value = F_text
            textbox_middle.value = ""
            textbox_bottom.value = F_dir
####### CASE 16 #######-------------------------------------------------------------------------------------#######
    elif case[0:2] == '16':
        if l == 'i': # Initial Report
            textbox_title.value = I_title
            textbox_top.value = I_text
            textbox_middle.value = "<br><b>Date of Incident:</b> March 30th <br>\
                                    <br><b>Location of Incident:</b> 115 Main Street, West Lansing, MI<br>"\
                                    + interview_list + request_xray
            textbox_bottom.value=""
        elif l == 'w': # Patient Interview
            textbox_title.value = W_title
            textbox_top.value = W_text
            textbox_middle.value="<br><ul><li>Was out for a run on Main Street</li>\
                                    <li>Enjoying the spring weather</li>\
                                    <li>Paying more attention to his music than what was in front of him</li>\
                                    <li>Tripped over a bicycle in the middle of the sidewalk!</li></ul>"
            textbox_bottom.value = PM_add
        elif l == 'e': # Dr. Emerald
            textbox_title.value = E_title
            textbox_top.value = E_text
            textbox_middle.value = "<br><ul><li>Driving down Main Street on the way back from his office</li>\
                                        <li>Saw a man on the sidewalk entangled with a bicycle</li>\
                                        <li>Called 911 and provided immediate first aid</li></ul>"
            textbox_bottom.value = E_add
        elif l == 't': # Mrs. Topaz
            textbox_title.value = T_title
            textbox_top.value = T_text
            textbox_middle.value="<br><ul><li>Wasn’t around at time of incident</li>\
                                        <li>Heard about it from friends when she got home</li>\
                                        <li>Almost everyone on the street has a bicycle</li>\
                                        <li>Best way to get around!</li></ul>"
            textbox_bottom.value = T_add
        elif l == 's': # Mr. Sapphire
            textbox_title.value = S_title
            textbox_top.value = S_text
            textbox_middle.value="<br><ul><li>Was inside his apartment hosting a board game night</li>\
                                        <li>Heard a crash outside</li>\
                                        <li>All bikes are required to be locked up</li>\
                                        <li>Not just learning against something</li>\
                                        <li>Most neighbors have bikes</li></ul>"
            textbox_bottom.value = S_add   
        elif l == 'a': # Prof. Amethyst
            textbox_title.value = A_title
            textbox_top.value = A_text
            textbox_middle.value="<br><ul><li>Had just come to Main Street to visit a good friend\
                                        for a night of board games</li>\
                                        <li>Doesn't own a car, but can't remember how she got\
                                        to Main Street that night (stayed up too late playing board games)</li>\
                                        <li>If she rode her bike, she always locks it in the bike rack!</li></ul>"
            textbox_bottom.value = A_add
        elif l == 'r': # Mr. Ruby
            textbox_title.value = R_title
            textbox_top.value = R_text
            textbox_middle.value="<br><ul><li>Was looking out the window at the sunset</li>\
                                        <li>Saw someone arrive across the street and leave their\
                                        bike leaning against a light post</li>\
                                        <li>They walked inside 115<li>\
                                        <li>About 30 minutes later, heard a crash and a yell</li>\
                                        <li>Has a <i>security camera</i> that is focused on the street</li></ul>"
            textbox_bottom.value = R_add 
        elif l == 'c': # Security Camera
            textbox_title.value = C_title
            textbox_top.value = C_text
            textbox_middle.value = ""
            textbox_bottom.value = C_dir
        elif l == 'f': # Footprints
            textbox_title.value = F_title
            textbox_top.value = F_text
            textbox_middle.value = ""
            textbox_bottom.value = F_dir   
####### ALL CASES #######-------------------------------------------------------------------------------------#######
#---Check click for duplicate, update code -----------------------------------
    if click.find(l) == -1:
        # new click
        click = click + l
        code = code + inv_code_d[l]
####### ID/Progress Code ENTRY ######################################################################
str_1 = widgets.HTML(value="Welcome to the team! We are glad to have your help to solve this case.")
str_2 = widgets.HTML(value="Please enter your <b>Case ID:</b>")
str_3 = widgets.HTML(value="Please enter your <b>Progress Code:</b>")
ID_Entry = widgets.Text(layout=widgets.Layout(width='70px'))
Prog_Entry = widgets.Text(layout=widgets.Layout(width='600px'))
Start = widgets.Button(description="START",disabled=False,style={'font_weight':'bold'},button_style='success')
str_4 = widgets.HTML(value="Confirm Case ID and Progress Code are correct, then press:")

ID_box = widgets.HBox([str_2, ID_Entry])
Prog_box = widgets.HBox([str_3, Prog_Entry])
Start_box = widgets.HBox([str_4, Start])  

button_intro = widgets.VBox([str_1, ID_box, Prog_box, Start_box])

disp_intro = widgets.VBox([button_intro])
####################
display(disp_intro)# introduction
####################

####### INVESTIGATOR TERMINAL ######################################################################
term = "<p style='color:white; background-color:black; padding:2px; text-align:center'>"
str_5 = widgets.HTML(value=term+"<b> INVESTIGATOR TERMINAL ME49500 </b></p>",)
str_6 = widgets.HTML(value=term+"<b> Action</b> <i>(1 word)</i> </p>",layout=widgets.Layout(width='150px'))
Key_Entry = widgets.Text(layout=widgets.Layout(width='150px'))
str_7 = widgets.HTML(value=term+"<b> Text</b> <i>(1-2 words)</i> </p>")
Text_Entry = widgets.Text()
str_8 = widgets.HTML(value=term+"<b> RESULT </b></p>",layout=widgets.Layout(width='300px'))
Result = widgets.HTML(value="<i> Enter an Action and Text, then press SUBMIT</i>",\
                      justify_content="center") # print error
Submit = widgets.Button(description="SUBMIT",disabled=True,style={'button_color':'#D3D3D3','font_weight':'bold'}) 

Key_box = widgets.VBox([str_6, Key_Entry])
Text_box = widgets.VBox([str_7, Text_Entry])
Result_box = widgets.VBox([str_8, Result])
box_layout = widgets.Layout(align_items='center')
Entry_box = widgets.HBox([Key_box, Text_box, Submit, Result_box],layout=box_layout)

box_layout = widgets.Layout(border='solid')
disp_invest = widgets.VBox([str_5, Entry_box],layout=box_layout)

####### PROGRESS CODE ##########################################################################
Prog_Code = widgets.Text(layout=widgets.Layout(width='600px'))
Prog_Button = widgets.Button(description="Generate Progress Code",disabled=True,\
                             style={'font_weight':'bold'}, button_style='danger',\
                             layout=widgets.Layout(width='200px'))
str_9 = widgets.HTML(value="<i> Make sure to generate your progress code before exiting.</i>")
str_10 = widgets.HTML(value="")

prog_box = widgets.HBox([Prog_Button, Prog_Code])
disp_prog = widgets.VBox([str_9, prog_box, str_10], layout=box_layout)

####### EVIDENCE BUTTONS ##########################################################################
# Initial blank image
Blank_im = open("B.png", "rb").read() # blank image for unlocked buttons   
im_wh = 40
layout = widgets.Layout(width='90px')
# Initial disabled buttons and blank images
I = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Initial Report Filing
I_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
P = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Patient Information
P_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
W = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Patient Interview
W_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
E = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Emerald
E_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
T = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Topaz
T_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
S = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Sapphire
S_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
A = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Amethyst
A_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
R = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Ruby
R_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
X = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # X-Ray
X_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
M = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Medical Record
M_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
C = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Security Camera
C_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
F = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Footprints
F_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
H = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Heights
H_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)
O = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'},layout=layout) # Shoe Sizes
O_i = widgets.Image(value=Blank_im, format='png', width=im_wh, height=im_wh)

box_layout = widgets.Layout(align_items='center')

case_info = widgets.HTML(value="<b>Case Information:</b>")
I_box = widgets.HBox([I, I_i],layout=box_layout)
P_box = widgets.HBox([P, P_i],layout=box_layout)
interviews = widgets.HTML(value = "<b>Interviews:</b>")
W_box = widgets.HBox([W, W_i],layout=box_layout)
E_box = widgets.HBox([E, E_i],layout=box_layout)
T_box = widgets.HBox([T, T_i],layout=box_layout)
S_box = widgets.HBox([S, S_i],layout=box_layout)
A_box = widgets.HBox([A, A_i],layout=box_layout)
R_box = widgets.HBox([R, R_i],layout=box_layout)
medical = widgets.HTML(value="<b>Medical Information:</b>")
X_box = widgets.HBox([X, X_i],layout=box_layout)
M_box = widgets.HBox([M, M_i],layout=box_layout)
additional = widgets.HTML(value="<b>Additional Evidence:</b>")
M_box = widgets.HBox([M, M_i],layout=box_layout)
C_box = widgets.HBox([C, C_i],layout=box_layout)
F_box = widgets.HBox([F, F_i],layout=box_layout)
H_box = widgets.HBox([H, H_i],layout=box_layout)
O_box = widgets.HBox([O, O_i],layout=box_layout)

# alpha order by last name for witnesses
IP_box = widgets.VBox([I_box, P_box])
AE_box = widgets.VBox([A_box, E_box])
RS_box = widgets.VBox([R_box, S_box])
TW_box = widgets.VBox([T_box, W_box])
XM_box = widgets.VBox([X_box, M_box])
FO_box = widgets.VBox([F_box, O_box])
CH_box = widgets.VBox([C_box, H_box])

box_layout = widgets.Layout(align_items='center',border='solid')
info_box = widgets.VBox([case_info, IP_box],layout=box_layout)
AERSTW_box = widgets.HBox([AE_box, RS_box, TW_box])
inter_box = widgets.VBox([interviews, AERSTW_box],layout=box_layout)
XMFOCH_box = widgets.HBox([XM_box, FO_box, CH_box])
evid_box = widgets.VBox([additional, XMFOCH_box],layout=box_layout)
disp_evid_buttons = widgets.HBox([info_box, inter_box, evid_box])

####### EVIDENCE INFO when CLICKED ##########################################################################
textbox_title = widgets.HTML(value='')
textbox_top = widgets.HTML(value='')
textbox_middle = widgets.HTML(value='')
textbox_bottom = widgets.HTML(value='')

evid_info = widgets.VBox([textbox_title,textbox_top,textbox_middle,textbox_bottom])

# Notebook spiral
N_i = widgets.Image(value=open("N.png", "rb").read(), format='png', width=90, height=360)
disp_notebook = widgets.HBox([N_i, evid_info])


disp_evid = widgets.VBox([disp_evid_buttons, disp_notebook])
#######################
display(disp_invest)  # investigator terminal
display(disp_evid)    # evidence
display(disp_prog)    # progress code
#######################

######## START BUTTON (Case + Code) ##########################################################
@Start.on_click
def Start_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    
    ID = ID_Entry.value
    IDtoCaseNumber()
    code = Prog_Entry.value
    CaseDictionary()
    CodetoClick()

#---#---------------------
    if case.find('Z') == -1 and click.find('Z') == -1 and code != 'Z': # check ID & code
        
        str_4.value = "Confirm Case ID and Progress Code are correct, then press:"
        case_info.value="<b>Case #" + ID + "</b>"              
        
        Start.disabled = True
        Prog_Button.disabled = False
        Submit.disabled = False
        
        evidencebuttons('I')
        evidencebuttons('P')
        
        # progress code
        for ii in range(len(click)):
            evidencebuttons(click[ii])             

#---#--------------------- 
    else:
        str_4.value = "<font color='red'><b>ERROR: Incorrect Progress Code and Case ID</font color></b>"                              

######## INVESTIGATOR TERMINAL SUBMIT BUTTON (Action + Text) ################################
@Submit.on_click    
def Submit_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    
    no_key = "<font color='red'><b> Invalid Action Input</font color></b>"
    no_text = "<font color='red'><b> Invalid Text Input</font color></b>"
    not_yet = "<font color='red'><b> Not <i>Currently</i> a Possible Action </font color></b>"
    
    key = Key_Entry.value
    text = Text_Entry.value
#--------------------------------------    
    if key == 'Interview' or key == 'interview':
        if text == 'E. Emerald' or text == 'e. emerald' or text == 'Emerald' or text == 'emerald':
            evidencebuttons('E')
            Result.value = "Interview Conducted"
        elif text == 'T. Topaz' or text == 't. topaz' or text == 'Topaz' or text == 'topaz':
            evidencebuttons('T')
            Result.value = "Interview Conducted"
        elif text == 'S. Sapphire' or text == 's. sapphire' or text == 'Sapphire' or text == 'sapphire':
            evidencebuttons('S')
            Result.value = "Interview Conducted"
        elif text == 'A. Amethyst' or text == 'a. amethyst' or text == 'Amethyst' or text == 'amethyst':
            evidencebuttons('A')
            Result.value = "Interview Conducted"
        elif text == 'R. Ruby' or text == 'r. ruby' or text == 'Ruby' or text == 'ruby':
            evidencebuttons('R')
            Result.value = "Interview Conducted"
        elif text == 'Patient' or text == 'patient':
            evidencebuttons('W')
            Result.value = "Interview Conducted"
        #----- Jane
        elif patient_d[case[0:2]][0]=='J' and (text == 'Jane' or text == 'jane'):
            evidencebuttons('W')
            Result.value = "Interview Conducted"
        #----- Henry
        elif patient_d[case[0:2]][0]=='H' and (text == 'Henry' or text == 'henry'):
            evidencebuttons('W')
            Result.value = "Interview Conducted"
        #----- Cynthia
        elif patient_d[case[0:2]][0]=='C' and (text == 'Cynthia' or text == 'cynthia'):
            evidencebuttons('W')
            Result.value = "Interview Conducted"
        #----- Michael
        elif patient_d[case[0:2]][0]=='M' and (text == 'Michael' or text == 'michael'):
            evidencebuttons('W')
            Result.value = "Interview Conducted"
        else:
            Result.value = no_text
#--------------------------------------    
    elif key == 'Request' or key == 'request':
        if text == 'XRay' or text == 'xray'  or text == 'Xray'\
                          or text == 'X-Ray' or text == 'x-ray' or text == 'x-Ray' or text == 'X-ray':
            evidencebuttons('X')
            Result.value = "XRay Obtained"
        elif text == 'Security Camera' or text == 'security camera' or text == 'Camera' or text == 'camera'\
                                       or text == 'Video Camera' or text == 'video camera'\
                                       or text == 'Video' or text == 'video':
            # if clicked correct witness statement before
            if click.find(case_d['C']) != -1:
                evidencebuttons('C')
                Result.value = "Security Camera Footage Obtained"
            else:
                Result.value = not_yet
        elif text == 'Footprints' or text == 'footprints' or text == 'Footprint' or text == 'footprint'\
                                  or text == 'Foot Prints' or text == 'foot prints' or text == 'Foot prints'\
                                  or text == 'Foot Print' or text == 'foot print' or text == 'Foot print':
            # if clicked correct witness statement before
            if click.find(case_d['F']) != -1:
                evidencebuttons('F')
                Result.value = "Footprint Evidence Obtained"
            else:
                Result.value = not_yet
        elif text == 'Heights' or text == 'heights' or text == 'Height' or text == 'height'\
                                  or text == 'Witness Heights' or text == 'witness heights' or text == 'Witness heights'\
                                  or text == 'Witness Height' or text == 'witness height' or text == 'Witness height':
            # if clicked camera footage before
            if click.find(case_d['H']) != -1:
                evidencebuttons('H')
                Result.value = "Witness Heights Obtained"
            else:
                Result.value = not_yet
        elif text == 'Shoe Sizes' or text == 'shoe sizes' or text == 'Shoe sizes'\
                                  or text == 'Shoe Size' or text == 'shoe size' or text == 'Shoe size'\
                                  or text == 'Shoes' or text == 'shoes' or text == 'Sizes' or text == 'sizes':
            # if clicked footprints before
            if click.find(case_d['O']) != -1:
                evidencebuttons('O')
                Result.value = "Witness Shoe Sizes Obtained"
            else:
                Result.value = not_yet
        else:
            Result.value = no_text
#--------------------------------------    
    elif key == 'Injury' or key == 'injury':  
            # if clicked xray before
            if click.find(case_d['M']) != -1:        
                #----- Wrist
                if patient_d[case[0:2]][1]=='w' and (text == 'Colles' or text == 'colles'\
                                                     or text == 'Distal Radius' or text == 'Distal radius'\
                                                     or text == 'distal radius'):
                    evidencebuttons('M')
                    Result.value ="Medical Record Obtained"
                #----- Elbow
                elif patient_d[case[0:2]][1]=='e' and (text == 'Olecranon' or text == 'olecranon'):
                    evidencebuttons('M')
                    Result.value ="Medical Record Obtained"
                #----- Hip
                elif patient_d[case[0:2]][1]=='h' and (text == 'Femoral Neck' or text == 'Femoral neck'\
                                                       or text == 'femoral neck'):
                    evidencebuttons('M')
                    Result.value ="Medical Record Obtained"
                #----- Jaw
                elif patient_d[case[0:2]][1]=='j' and (text == 'Mandibular Ramus'\
                                                       or text == 'Mandibular ramus' or text == 'mandibular ramus'):
                    evidencebuttons('M')
                    Result.value ="Medical Record Obtained"
                #----- INCORRECT
                else:
                    Result.value = no_text
            else:
                Result.value = not_yet   
#--------------------------------------    
    else:
        Result.value = no_key

###### GENERATE PROGRESS CODE ##########################################################################
@Prog_Button.on_click    
def Prog_button_clicked(a):    
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    Prog_Code.value = code # update progress code
    I.disabled=True
    P.disabled=True
    W.disabled=True
    E.disabled=True
    T.disabled=True
    S.disabled=True
    A.disabled=True
    R.disabled=True
    X.disabled=True
    M.disabled=True
    C.disabled=True
    F.disabled=True
    H.disabled=True
    O.disabled=True
    Submit.disabled=True
    Prog_Button.disabled=True
    str_10.value = "<b>Session completed.</b> Please save this case-sensitive <b>Progress Code</b> and your <b>Case ID</b>"

###### EVIDENCE BUTTONS ################################################################################
@I.on_click    
def I_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('i')
    
##########
@P.on_click    
def P_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('p')

##########        
@W.on_click
def W_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('w')

##########        
@E.on_click
def E_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('e')

##########
@T.on_click
def T_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('t')

##########
@S.on_click    
def S_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d 
    updateevidence('s')

##########
@A.on_click
def A_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('a')

##########
@R.on_click
def R_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('r')

##########
@X.on_click    
def X_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('x')

##########
@M.on_click    
def M_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('m')
    
##########
@C.on_click    
def C_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('c')
    
##########
@F.on_click    
def F_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('f')   
##########
@H.on_click    
def H_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('h')
##########
@O.on_click    
def O_clicked(a):
    global click, case, ID, code, code_d, inv_code_d, case_d, patient_d
    updateevidence('o')
# Out:
# VBox(children=(VBox(children=(HTML(value='Welcome to the team! We are glad to have your help to solve this cas…
# VBox(children=(HTML(value="<p style='color:white; background-color:black; padding:2px; text-align:center'><b> …
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<b>Case #1001</b>'), VBox(children=(HBox(children=(Bu…
# VBox(children=(HTML(value='<i> Make sure to generate your progress code before exiting.</i>'), HBox(children=(…
